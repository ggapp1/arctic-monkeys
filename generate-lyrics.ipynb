# %% [markdown]
# ## Using a LSTM to try to generate new monkeys' songs.
# First, we'll do a bunch of importing

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io
import string, re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import itertools

# %% [markdown]
# Cleaning the text...

# %%
def remove_punc(lyrics):
    return "".join([c for c in lyrics if c not in string.punctuation])
def remove_stopwords(lyrics):
    return [w for w in lyrics if w not in stopwords.words('english')]

markers = ['[', ']','Verse','1','2','3','Chorus','Spoken Intro','Intro','Bridge','PreChorus', 'and','And','Outro']

def remove_markers(lyrics):
    return [w for w in lyrics if w not in markers]

lyrics_df = pd.read_csv('data/lyrics.csv')
tokenizer = RegexpTokenizer(r'\w+')

lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: remove_punc(x))
lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: tokenizer.tokenize(x))
lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: remove_markers(x))

# %% [markdown]
# Formating the text to the lstm...

# %%
def format_lyrics(lyrics, maxlen, step):
    text = list(itertools.chain.from_iterable(lyrics))
    text = ' '.join(text)
    chars = sorted(list(set(text)))
    print('total chars:', len(chars))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))

    # cut the text in semi-redundant sequences of maxlen characters
    
    sentences = []
    next_chars = []
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
    print('nb sequences:', len(sentences))

    print('Vectorization...')
    x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
        
    return chars, char_indices, indices_char, x, y, text

# %% [markdown]
# We'll only use the lyrics from tbh&c

# %%
maxlen = 50
step = 3
tbhc_lyrics = lyrics_df[lyrics_df['album'] == 'Tranquility Base Hotel & Casino']
tbhc_lyrics = tbhc_lyrics['lyrics'].values

chars, char_indices, indices_char, x, y, text = format_lyrics(tbhc_lyrics, maxlen, step)
# Out:
# total chars: 57
# nb sequences: 4297
# Vectorization...

# %% [markdown]
# Now, defining the model and using some functions to visualize the process, based on [this tutorial](https://keras.io/examples/lstm_text_generation/)

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    if(((epoch+1)%15) != 0 ):
        return
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
# Out:
# Build model...

# %%
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 4297/4297 [==============================] - 5s 1ms/step - loss: 3.2061
#
# Epoch 2/60
# 4297/4297 [==============================] - 4s 843us/step - loss: 3.0320
#
# Epoch 3/60
# 4297/4297 [==============================] - 4s 858us/step - loss: 3.0246
#
# Epoch 4/60
# 4297/4297 [==============================] - 4s 889us/step - loss: 3.0258
#
# Epoch 5/60
# 4297/4297 [==============================] - 4s 844us/step - loss: 3.0224
#
# Epoch 6/60
# 4297/4297 [==============================] - 4s 848us/step - loss: 3.0154
#
# Epoch 7/60
# 4297/4297 [==============================] - 4s 844us/step - loss: 2.9953
#
# Epoch 8/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 2.8260
#
# Epoch 9/60
# 4297/4297 [==============================] - 4s 846us/step - loss: 2.7373
#
# Epoch 10/60
# 4297/4297 [==============================] - 4s 866us/step - loss: 2.6225
#
# Epoch 11/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 2.5504
#
# Epoch 12/60
# 4297/4297 [==============================] - 4s 850us/step - loss: 2.4722
#
# Epoch 13/60
# 4297/4297 [==============================] - 4s 849us/step - loss: 2.4035
#
# Epoch 14/60
# 4297/4297 [==============================] - 4s 844us/step - loss: 2.3314
#
# Epoch 15/60
# 4297/4297 [==============================] - 4s 866us/step - loss: 2.2570
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " a singer must die Singsong Round the Money Tree T"
#  a singer must die Singsong Round the Money Tree The louk the louk the ste ste pore the ste pe the woth the been the male the woth a lou the stor the the be in the woth the wath the pont on the wole fo the that a lou the lole fon a lou ghat a lou that the ste whon the ball the bole fou what a lou the wole fon the louk the bot the woth the the ste pand the the pont the the loth the u lou the pond the pon the wose that the goun the loth that a liut
# ----- diversity: 0.5
# ----- Generating with seed: " a singer must die Singsong Round the Money Tree T"
#  a singer must die Singsong Round the Money Tree Thit the puth ant thit a lout on ant fot awt tho nath ons a pout the loth thimang e killl the pinod the houn wond ming by the with the wine in that thang a hive fot a lout find thats thont sp thite dor de the pith a pille look risp the brase the bort a lout ceoun poun that in Me thast the paon a louke woml ming the bont fo in eant the thare feocand the party Int e lighl a laut the gime a lou bee wh
# ----- diversity: 1.0
# ----- Generating with seed: " a singer must die Singsong Round the Money Tree T"
#  a singer must die Singsong Round the Money Tree The not the peasat yours Iht chy bighes ad fyey mink ut msanef hralhorl sasroth givp yiukarl my fhrot thile ghe blf lydhangy Inb hoys ting picione you lhe you The kroneg wyt dod u lomkler mosdldase Lathe Thit frarce wenty Thoaghl wrhandlirg ale insh aucede mee Saoty Clr austeade th by doy avler you gct thasgy Ctot antire parl mo afsy lomt phast ly mvatang Rath thengio I pam Thouun w uf phe lhi bucl
# ----- diversity: 1.2
# ----- Generating with seed: " a singer must die Singsong Round the Money Tree T"
#  a singer must die Singsong Round the Money Tree Thadp drepmeeespang oviuntlinn gotens kate Brous thet inm inltine vhily Ey ghumpogasetctlooes ne wove f lewccapkeodh ti uchs Tims fticre It of feee mtole wac Tike the stess woom theleaglt cordals thond fhildent e gook sash e a pikiged Aum an isatittachy wya ghamy fhopacl e jyee gor s suut Al Pyeety Thithmane h nl hisp Yhiuuph a weod pire I betland in thes eflume tto the ghawd smreedpplle bonughe we
# Epoch 16/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 2.1752
#
# Epoch 17/60
# 4297/4297 [==============================] - 4s 851us/step - loss: 2.0828
#
# Epoch 18/60
# 4297/4297 [==============================] - 4s 857us/step - loss: 2.0008
#
# Epoch 19/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 1.9176
#
# Epoch 20/60
# 4297/4297 [==============================] - 4s 861us/step - loss: 1.8333
#
# Epoch 21/60
# 4297/4297 [==============================] - 4s 861us/step - loss: 1.7246
#
# Epoch 22/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 1.6247
#
# Epoch 23/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 1.5244
#
# Epoch 24/60
# 4297/4297 [==============================] - 4s 858us/step - loss: 1.4171
#
# Epoch 25/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 1.3117
#
# Epoch 26/60
# 4297/4297 [==============================] - 4s 863us/step - loss: 1.2106
#
# Epoch 27/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 1.1119
#
# Epoch 28/60
# 4297/4297 [==============================] - 4s 861us/step - loss: 1.0428
#
# Epoch 29/60
# 4297/4297 [==============================] - 4s 858us/step - loss: 0.9307
#
# Epoch 30/60
# 4297/4297 [==============================] - 4s 855us/step - loss: 0.8608
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "e looks like fun Bukowski She looks like fun Dogsi"
# e looks like fun Bukowski She looks like fun Dogsitioo fears That I hau thieed the looks like fun She looks like funevt Ine got a liller the hande eot ofection Ratio in te the way some stey with u wan the dotting She looks like fun She looks like fun She looks leend to bake it easeenedyose I nele waeed the meod your mewwinie in the bend Bue Ste looks like fun She looks like fun She looks liet foe Stand they eet the back in theeedatsed the got a l
# ----- diversity: 0.5
# ----- Generating with seed: "e looks like fun Bukowski She looks like fun Dogsi"
# e looks like fun Bukowski She looks like fun Dogsitioo frisst Anme in the deedrifory woll in me elo got a little woth u nilling roit four the meng the love in the diot frim anot for a little with u nengrion drall the pratcon cell dornt the look Standf froends Inme beve bears you the dot thoe1Meed sust in timee me indityry InmertionAction Rertion Ratio In the dant stowd those Tuke it easy for a little onbe things that I hau namy fror a listion dea
# ----- diversity: 1.0
# ----- Generating with seed: "e looks like fun Bukowski She looks like fun Dogsi"
# e looks like fun Bukowski She looks like fun Dogsitioe your that I hanevadeeed isotion doent of for my mert the loterting blobing spomms on bearani walp best to etey catcersy Eutter wance me froe anot it forfened womfaty I paude anmertionActionA tre Mascer Ohe wath n thoendsssselly Itser to mert four a lieTtirs Thapped pqin thot frut a have ov in the reasight neg it you stey time the meng on Maybe newgy hot thought four that I hepe stot I mot to
# ----- diversity: 1.2
# ----- Generating with seed: "e looks like fun Bukowski She looks like fun Dogsi"
# e looks like fun Bukowski She looks like fun Dogsing 1 patvlr Nuin to you teevfr ot starn om a lilt for wulled cctsts way to the dond in the dickle beallink plecedy Cuwe Touds Thinkf nem those Wopkey Cent of the buch nest lovave its to dimery in myots you nsver pilvyr on timesdedty now sloce De us up the dave hiit a ment Sho wangong they doon cost Bubvhr Oultight thiegsModhap in my ey it for a lime sharloed my in the dot my boke Tutrend spruls hi
# Epoch 31/60
# 4297/4297 [==============================] - 4s 851us/step - loss: 2.0160
#
# Epoch 32/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 3.0908
#
# Epoch 33/60
# 4297/4297 [==============================] - 4s 851us/step - loss: 3.1539
#
# Epoch 34/60
# 4297/4297 [==============================] - 4s 849us/step - loss: 3.3490
#
# Epoch 35/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 3.0564
#
# Epoch 36/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 3.0855
#
# Epoch 37/60
# 4297/4297 [==============================] - 4s 857us/step - loss: 3.0541
#
# Epoch 38/60
# 4297/4297 [==============================] - 4s 854us/step - loss: 2.9124
#
# Epoch 39/60
# 4297/4297 [==============================] - 4s 858us/step - loss: 2.4432
#
# Epoch 40/60
# 4297/4297 [==============================] - 4s 857us/step - loss: 1.8275
#
# Epoch 41/60
# 4297/4297 [==============================] - 4s 859us/step - loss: 1.1109
#
# Epoch 42/60
# 4297/4297 [==============================] - 4s 855us/step - loss: 0.8748
#
# Epoch 43/60
# 4297/4297 [==============================] - 4s 845us/step - loss: 0.7762
#
# Epoch 44/60
# 4297/4297 [==============================] - 4s 850us/step - loss: 0.6827
#
# Epoch 45/60
# 4297/4297 [==============================] - 4s 855us/step - loss: 0.6284
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "n bars Waffling on to strangers all about martial "
# n bars Waffling on to strangers all about martial a wan looking on port fleaned Ill be me in the beterner Pand speaking Ple It so nall the beterning Sle mened love You kust the beon Bler to your call Inst to mity you uvler She looks like fun She looks like fun She looking on poll to the best Bant so you with u wat a will four anterner to mitio I dove me in the beod Pance Singor Owarder Ole were Time to mititill I jupt anmot all got all got all on
# ----- diversity: 0.5
# ----- Generating with seed: "n bars Waffling on to strangers all about martial "
# n bars Waffling on to strangers all about martial a night four stars tike Lete Bint time the bent exout youv your call Bint in me ece a got a list the meon The bent so y ur fiction does Yoe my make A cante to mity you on the memery for a little with youd too trr that tre beon The beciew the looking on porn exgling So whit a can looking op for a little wit look stows feve me in the meon Tre looks like fun She looks like fun She looking on poll to
# ----- diversity: 1.0
# ----- Generating with seed: "n bars Waffling on to strangers all about martial "
# n bars Waffling on to strangers all about martial cled to mingors Casino Sle like fun Blot dreane I cante four nort to e stoy looks like fun She looks like fun K stay stare were on the meod Tre mese if the best Bnove Buck um hive hove me in the maon doond to fee love you uvl the looking on fol all Thane Tamarilily werle biltt the meon Trem my make Hever to exll ovo ress hot nace Sye looks like fun Barf down dover my my me keer mler Treaned all go
# ----- diversity: 1.2
# ----- Generating with seed: "n bars Waffling on to strangers all about martial "
# n bars Waffling on to strangers all about martial a nistor Cloadty Ciglt time the meon Tent the teter seuck vints four you rack hood She looking one tho Ill atstr on Mot too who buon modily anderne Tion Elors Awarst Eter harwat thandf atte west moy tions cang the cave keeaned hlined the best You ktewby reod You pust the hittlif out of doll exoutithe instor trom be you uvle wonent roat dicke To bhe cittl your youe rewipigily im tre thinkf strens s
# Epoch 46/60
# 4297/4297 [==============================] - 4s 847us/step - loss: 0.5356
#
# Epoch 47/60
# 4297/4297 [==============================] - 4s 851us/step - loss: 0.5024
#
# Epoch 48/60
# 4297/4297 [==============================] - 4s 849us/step - loss: 0.4674
#
# Epoch 49/60
# 4297/4297 [==============================] - 4s 848us/step - loss: 0.4251
#
# Epoch 50/60
# 4297/4297 [==============================] - 4s 846us/step - loss: 0.3872
#
# Epoch 51/60
# 4297/4297 [==============================] - 4s 853us/step - loss: 0.3617
#
# Epoch 52/60
# 4297/4297 [==============================] - 4s 847us/step - loss: 0.3397
#
# Epoch 53/60
# 4297/4297 [==============================] - 4s 845us/step - loss: 0.3441
#
# Epoch 54/60
# 4297/4297 [==============================] - 4s 851us/step - loss: 0.3070
#
# Epoch 55/60
# 4297/4297 [==============================] - 4s 853us/step - loss: 0.2887
#
# Epoch 56/60
# 4297/4297 [==============================] - 4s 856us/step - loss: 0.3200
#
# Epoch 57/60
# 4297/4297 [==============================] - 4s 852us/step - loss: 0.2725
#
# Epoch 58/60
# 4297/4297 [==============================] - 4s 848us/step - loss: 0.2545
#
# Epoch 59/60
# 4297/4297 [==============================] - 4s 853us/step - loss: 0.2517
#
# Epoch 60/60
# 4297/4297 [==============================] - 4s 853us/step - loss: 0.2376
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: " a little while Take it easy for a little while Co"
#  a little while Take it easy for a little while Come stay bights thingst the goods Brom to you they my in the sich eng hoit I jupe at the sicke rewop Voghing She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She looks like fun She loo
# ----- diversity: 0.5
# ----- Generating with seed: " a little while Take it easy for a little while Co"
#  a little while Take it easy for a little while Come stay bights thingst I pupe I poud adlertion Ratio I doud your yout you whene meught on the wall in beaune The arl gaod Vogut Iv the sicke Ste looks like fun She looks like fun She looks like fun She looks like fun She looks like fun Bnawall in meaging I pope stoy bights that I juge atserse Neher dornang Please tell me how may I direct your call doll dings wight the battlone Im the sicheent than
# ----- diversity: 1.0
# ----- Generating with seed: " a little while Take it easy for a little while Co"
#  a little while Take it easy for a little while Come stiy bocke Is such anout exoutdy fice it easy for a little while Cume I sepe The Macky nights thingse InformationAction Ratio Inbe I goud vived to bity I wall adout the sucke skuends aroon Tranquility meng The mallen callen does You trrough to dity The goodangore if the mality my ut the battle thingss Shat I haud anternoon Tranquility Base Howe Bat a ligelle one things cack do you whanqthe crac
# ----- diversity: 1.2
# ----- Generating with seed: " a little while Take it easy for a little while Co"
#  a little while Take it easy for a little while Come st y bust in a soll beed anternoon triters that I junt exout yoo ontseratyrerer Aasing in be baybe Exace fight chawe i stoy mine whay drit I directay thing mockle how mays I jupt anmertion Ratio I caud stor Ot just ece by e sharabicing in me balmy ment you what in meationAction Ratio In the srare hike it eloy fiut shreame I caud stary out of five Lonale Ingernoon Tranquility mromqwerirds Batter
