# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io
import string, re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import itertools

def remove_punc(lyrics):
    return "".join([c for c in lyrics if c not in string.punctuation])
def remove_stopwords(lyrics):
    return [w for w in lyrics if w not in stopwords.words('english')]

markers = ['[', ']','Verse' ,'1', '2','3', 'Chorus', 'Spoken Intro', 'Intro', 'Bridge', 'Outro']

def remove_markers(lyrics):
    return [w for w in lyrics if w not in markers]


lyrics_df = pd.read_csv('data/lyrics.csv')
tokenizer = RegexpTokenizer(r'\w+')

lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: remove_punc(x))
lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: tokenizer.tokenize(x))
lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: remove_markers(x))
#lyrics_df['lyrics'] = lyrics_df['lyrics'].apply(lambda x: remove_stopwords(x))

text = lyrics_df['lyrics'].values
text = list(itertools.chain.from_iterable(text))
text = ' '.join(text)
print(text)
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Youve never met before But still she greets you like a long lost rock n roll Shes definitely one of those Where youll go wherever she goes And with my body on my mind Both stop talking at the exact same time Trying to think of ways to make her mine But theyre difficult to find Its not what I need No your loves not what I need So dont give it to me And she said Oh well I know this will sound cold but I really have to go No its not that Im not free theres nowhere I need to be Its just your loves not what I need so dont give it to me Its not what I need No your loves not what I need So dont give it to me And she said Baby how can I believe you How can I believe you when you cant believe your luck No point sticking to the plan when its come unstuck Its more a hunger than a thirst Shell break your heart the second time Before you know about the first Looks well equipped to leave you in the lurch But youd let her do her worst And its not hard to tell Its obvious the other angels faces fell When she told him that she had to go Swapped her wings and overcoat for something colourful Tha knows Its not what I need No your loves not what I need So dont give it to me No your loves not what I need So dont give it to me No your loves not what I need So dont give it to me No your loves not what I need So dont give it to me Your loves not what I need In a foreign place the saving grace was the feeling That it was a heart that he was stealing Oh he was ready to impress and the fierce excitement The eyes are bright he couldnt wait to get away And I bet that Juliet was just the icing on the cake Make no mistake no And even if somehow we could have Shown you the place you wanted Well Im sure you could have Made it that bit better on your own And I bet she told a million people that shed stay in touch But all the little promises they dont mean much When theres memories to be made And I hope youre holding hands by New Years Eve They made it far too easy to believe That true romance cant be achieved these days And even if somehow they could have Shown you the place you wanted Well Im sure you could have Made it that bit better on your own You are the only ones who know Arabellas got some interstellargator skin boots An a Helter Skelter round her little finger An I ride it endlessly Shes got a Barbarella silver swimsuit An when she needs to shelter from reality She takes a dip in my daydreams My days end best when the sunset gets itself behind That little lady sittin on the passenger side Its much less picturesque without her catchin the light The horizon tries but its just not as kind on the eyes As Arabella oh As Arabella PostChorus Just might ve tapped into your mind and soul You cant be sure Arabellas got a 70s head But shes a modern lover Its an exploration shes made of outer space An her lips are like the galaxys edge An her kiss the colour of a constellation Fallin into place My days end best when the sunset gets itself behind That little lady sittin on the passenger side Its much less picturesque without her catchin the light The horizon tries but its just not as kind on the eyes As Arabella oh As Arabella PostChorus Just might ve tapped into your mind and soul You cant be sure Thats magic In a cheetah print coat Just a slip Underneath it I hope Asking if I can have one of those Organic Cigarettes that she smokes Wraps her lips Round a Mexican Coke Makes you wish That you were the bottle Takes a sip Of your soul an it sounds like Guitar Solo Just might ve tapped into your mind and soul You cant be sure Get out the way mister With your short sharp tips No I wont read your lips right now And baby hey You send a shiver down my spine But do you read my mind Do you And youre looking pretty suspicious And probably planning a heist Hes wanting to go to the strippers It makes him feel all nice Cigarette smoke yeah The cigarette smoke in your eyes Watching a stripper and Smacking a bloke yeah Smacking a bloke here tonight Get out my way mister With you ...
# total chars: 68
# nb sequences: 53622
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    if(((epoch+1)%15) != 0 ):
        return
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
# Out:
# Build model...

# %%
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 53622/53622 [==============================] - 14s 270us/step - loss: 2.2797
#
# Epoch 2/60
# 53622/53622 [==============================] - 13s 247us/step - loss: 1.9262
#
# Epoch 3/60
# 53622/53622 [==============================] - 13s 236us/step - loss: 1.6899
#
# Epoch 4/60
# 53622/53622 [==============================] - 13s 236us/step - loss: 1.5604
#
# Epoch 5/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 1.4608
#
# Epoch 6/60
# 53622/53622 [==============================] - 13s 235us/step - loss: 1.3812
#
# Epoch 7/60
# 53622/53622 [==============================] - 13s 235us/step - loss: 1.3183
#
# Epoch 8/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 1.2694
#
# Epoch 9/60
# 53622/53622 [==============================] - 13s 236us/step - loss: 1.2328
#
# Epoch 10/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 1.2018
#
# Epoch 11/60
# 53622/53622 [==============================] - 13s 236us/step - loss: 1.1730
#
# Epoch 12/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 1.1380
#
# Epoch 13/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 1.1361
#
# Epoch 14/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 1.1167
#
# Epoch 15/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 1.0915
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " Oh no its something for those beads of sweat Yes that will "
#  Oh no its something for those beads of sweat Yes that will never walls you to think the most the thing to stand the looks like a sture to stay mind and the posting right man And the only every my made you cant get off go go year the more they want to me of she was something and you to the conces And the concess And the only eve you mine I wanna be yours Wanna be yours Wanna be yours Wanna be yours I dont get of cones doing Left the mormagion alreable all
# ----- diversity: 0.5
# ----- Generating with seed: " Oh no its something for those beads of sweat Yes that will "
#  Oh no its something for those beads of sweat Yes that will whind If the slack on the sear right my mand And when you see  Now They said it wont get heart man And the conds enders love wall to the same thing what its a seets one of you know when the sun goes down And I wont get the trapper with the shind for now the first to strange Your have are so dark heavo the posting are good on the first to light The lights And change you everybodiomy eyes of a gune
# ----- diversity: 1.0
# ----- Generating with seed: " Oh no its something for those beads of sweat Yes that will "
#  Oh no its something for those beads of sweat Yes that will while arnthe Im something infeen Crinele dirmy wengly Bnight here well ways a goy a brut I push I had hearpint go defingits if a seemh to highan to on like and your knot will little Loug long and difead to saming Im ant they pleave you quettremention and nights in their sting around Yeah the holoss And he dreasos the first how Are there well me You reply I wall I wanna be yours That now round last
# ----- diversity: 1.2
# ----- Generating with seed: " Oh no its something for those beads of sweat Yes that will "
#  Oh no its something for those beads of sweat Yes that will on the tame and get his huld And emotion the guid Are but dont might do jowned on up onct getto into mine If theyds behind Instrume nowhobout thought all gettong  insamina rulla on who smose Ins always onet imbought hereCrifes a thow Teat the marl Can es The diffespenchended on clove And genticy and whos Im a bortipe talk dont gizzi Hed Hes cepes on a rilet whit ho And you say a lottle place As Al
# Epoch 16/60
# 53622/53622 [==============================] - 13s 244us/step - loss: 1.0803
#
# Epoch 17/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 1.0626
#
# Epoch 18/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 1.0461
#
# Epoch 19/60
# 53622/53622 [==============================] - 13s 239us/step - loss: 1.0305
#
# Epoch 20/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 1.0187
#
# Epoch 21/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 1.0146
#
# Epoch 22/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 1.0019
#
# Epoch 23/60
# 53622/53622 [==============================] - 13s 239us/step - loss: 0.9914
#
# Epoch 24/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 0.9820
#
# Epoch 25/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 0.9718
#
# Epoch 26/60
# 53622/53622 [==============================] - 13s 247us/step - loss: 0.9632
#
# Epoch 27/60
# 53622/53622 [==============================] - 14s 261us/step - loss: 0.9469
#
# Epoch 28/60
# 53622/53622 [==============================] - 14s 258us/step - loss: 0.9428
#
# Epoch 29/60
# 53622/53622 [==============================] - 13s 249us/step - loss: 0.9380
#
# Epoch 30/60
# 53622/53622 [==============================] - 12s 229us/step - loss: 0.9292
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "detect the fiction on your lips and dig a contradiction up A"
# detect the fiction on your lips and dig a contradiction up And they look to stand and the same It move along and the same It move along and your hand on tround And when youre so dark baby I say anywhered to start in the condsed to spend of you something to start in the chies I want you look an the sensh of you have are you have around Im strange Hown the sensh of you stop down And they said it changes when the sun goes do you know it in your stop come on c
# ----- diversity: 0.5
# ----- Generating with seed: "detect the fiction on your lips and dig a contradiction up A"
# detect the fiction on your lips and dig a contradiction up And they seel a bright the lights And they look an youre not gonna en sure Im like a start in the parlice like a pretty first the looks and then like a sengere a secteat Singhanse you found there in your shous stop colled I dont carred in the bark time Its the same Instrumental break So for the startain But it fisse they want to see lly my laughthing and you know nothing to dive and get the train i
# ----- diversity: 1.0
# ----- Generating with seed: "detect the fiction on your lips and dig a contradiction up A"
# detect the fiction on your lips and dig a contradiction up And she have around me through Well andHall you probably move Its noth Iystreumental Sand lack thes not are see line a bet she walts be the only romay And your Burtome come on your just to igse moron yeah But theyve get us So give I shouldnt be Yours I all go Yead youreen see like to come You sever lover Yeah making you in the grig Dhes and Take no fool in the gluss sefee a secteats from teat a roo
# ----- diversity: 1.2
# ----- Generating with seed: "detect the fiction on your lips and dig a contradiction up A"
# detect the fiction on your lips and dig a contradiction up And ow Oly youve saving out of muttering for to Watsay vishing and then inAck the queLtin to glun AndWtHing got ale frotted bite flack ladgroplall la back badaaalasady conget someghing when Im you say the sidd of a leven walked in the key baby Youre baby I say an emotivals your turner Bight boods And there going band ast takes Im joining ever here you lobitt The heous nelleck reasy and tay dpep eve
# Epoch 31/60
# 53622/53622 [==============================] - 13s 244us/step - loss: 0.9165
#
# Epoch 32/60
# 53622/53622 [==============================] - 13s 242us/step - loss: 0.9132
#
# Epoch 33/60
# 53622/53622 [==============================] - 13s 245us/step - loss: 0.9083
#
# Epoch 34/60
# 53622/53622 [==============================] - 14s 252us/step - loss: 0.8958
#
# Epoch 35/60
# 53622/53622 [==============================] - 13s 247us/step - loss: 0.8852
#
# Epoch 36/60
# 53622/53622 [==============================] - 14s 254us/step - loss: 0.8780
#
# Epoch 37/60
# 53622/53622 [==============================] - 13s 246us/step - loss: 0.8706
#
# Epoch 38/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 0.8632
#
# Epoch 39/60
# 53622/53622 [==============================] - 13s 245us/step - loss: 0.8584
#
# Epoch 40/60
# 53622/53622 [==============================] - 13s 235us/step - loss: 0.8542
#
# Epoch 41/60
# 53622/53622 [==============================] - 13s 244us/step - loss: 0.8395
#
# Epoch 42/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 0.8320
#
# Epoch 43/60
# 53622/53622 [==============================] - 13s 234us/step - loss: 0.8270
#
# Epoch 44/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 0.8237
#
# Epoch 45/60
# 53622/53622 [==============================] - 12s 233us/step - loss: 0.8184
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: " mix Said Youre mistaken if youre thinking That I havent bee"
#  mix Said Youre mistaken if youre thinking That I havent been were girls are see might be the strust the train of a there And they said it changes when the sun goes down Around her strunge In the cind and cracks to me back to me I want yourres me when youre high And there wont be arm again But this vormictly was something to the cirshor coul And there wont batt and the scume and stole well be my baby I cant the boys you are short its all about her the feet
# ----- diversity: 0.5
# ----- Generating with seed: " mix Said Youre mistaken if youre thinking That I havent bee"
#  mix Said Youre mistaken if youre thinking That I havent been were girls Sure The fussear was something to the fings And theres reas that you cant take out here wont neart the feeling easy the lights And at the eyes And the afternoon And they loved well are the hiss But youre not gonna crecking the eyes And we got the cool So up and the screets Cause then the sun goes down Are you rever me serepy good the prost off of a tentation of a trad to and the wross
# ----- diversity: 1.0
# ----- Generating with seed: " mix Said Youre mistaken if youre thinking That I havent bee"
#  mix Said Youre mistaken if youre thinking That I havent been words the wrong thues oker down you cammable So seen Theres anywouse be were murny me clusken that Im for too soulvition in man suat BeeW doinn the tarce And do I dont the wrock of cracilion Blad it Ress selining when us is ach Do they maw I pintire for on me to me baby Your hair And the bender Told thes well soute it Hes an hell keeling Calless to start to int too hirre to if If I hat have any
# ----- diversity: 1.2
# ----- Generating with seed: " mix Said Youre mistaken if youre thinking That I havent bee"
#  mix Said Youre mistaken if youre thinking That I havent been before I cant that you meet Flanger wouldnt words The wrone Are you couldner Wasnt to bear Shell reterres Dont he beam your htiod Oh she wont meando timy for see that were think of youre here croper thing If you need Do youck When now Well oreAtion that ach Well fut me my dancel on You and He could be but things Too the seen The slace but its Come left mim hebe it words with my fied partnin coul
# Epoch 46/60
# 53622/53622 [==============================] - 13s 241us/step - loss: 0.8076
#
# Epoch 47/60
# 53622/53622 [==============================] - 13s 249us/step - loss: 0.8055
#
# Epoch 48/60
# 53622/53622 [==============================] - 13s 237us/step - loss: 0.8027
#
# Epoch 49/60
# 53622/53622 [==============================] - 13s 243us/step - loss: 0.7913
#
# Epoch 50/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 0.7935
#
# Epoch 51/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 0.7806
#
# Epoch 52/60
# 53622/53622 [==============================] - 13s 240us/step - loss: 0.7768
#
# Epoch 53/60
# 53622/53622 [==============================] - 13s 241us/step - loss: 0.7649
#
# Epoch 54/60
# 53622/53622 [==============================] - 13s 242us/step - loss: 0.7659
#
# Epoch 55/60
# 53622/53622 [==============================] - 13s 246us/step - loss: 0.7624
#
# Epoch 56/60
# 53622/53622 [==============================] - 13s 248us/step - loss: 0.7567
#
# Epoch 57/60
# 53622/53622 [==============================] - 13s 239us/step - loss: 0.7565
#
# Epoch 58/60
# 53622/53622 [==============================] - 13s 238us/step - loss: 0.7563
#
# Epoch 59/60
# 53622/53622 [==============================] - 13s 239us/step - loss: 0.7496
#
# Epoch 60/60
# 53622/53622 [==============================] - 13s 239us/step - loss: 0.7461
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: " This right here I swear will end too soon My limbs seem to "
#  This right here I swear will end too soon My limbs seem to strupble And the pretty femes a silver frighted to scrop bound Youre so darke right hard to myse Hed to be arreams throught And the shabes up s it at the scust love Oh you cant light end so misscass the sink for you looking for the strange And it in the bark for own And I wanna got half and the scomen of to my me with the sippers that looks love its all the sun goes down Around y
# /home/ggapp/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
# our houses it easy
# ----- diversity: 0.5
# ----- Generating with seed: " This right here I swear will end too soon My limbs seem to "
#  This right here I swear will end too soon My limbs seem to hate youve up all too do the strange by underst the pantere forever horrow both good girl dine the languater mome and chaital PreChorus And I wasnt I wanna how down the seat Yeah of a wanna called Cruck in the innt about though Id the day after strange Wout she wont cant the shadin ty the strangate Try now in your store Bruah The only clont the teasy to bring and chaCt the wroughthing about it so
# ----- diversity: 1.0
# ----- Generating with seed: " This right here I swear will end too soon My limbs seem to "
#  This right here I swear will end too soon My limbs seem to hire You thoughts you the sightt The op shes They dont own I know the oplen leen Or throw of it Do by brick Waving and queen steah SaWhthere youre to stand my mind no Gook the ves disto from the tyo you down offeptionssed It wanna gote partening cause I know hord for my nawn And it is a swapped thinking eyes are through the startad And exacts When youre here to Prequnning Its not a feeling Dont cr
# ----- diversity: 1.2
# ----- Generating with seed: " This right here I swear will end too soon My limbs seem to "
#  This right here I swear will end too soon My limbs seem to be atrampel The will never birds All you cush it werroless around Im mads if out mirror And he no just Wid of it But stalte Hed words friend might at again But then away Its the prooes doose we lone Hes angught undight Its all about through and on king its about shinme but duching peting up and getted the rain in the queutinched lifrosed me su PusAsi diver theres ings clace Sit in up all these mac

# %%
#test other achitecture

model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), return_sequences=True))
#model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
#model.add(Dropout(0.2))
model.add(LSTM(128))
#model.add(Dropout(0.2))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.fit(x, y,
          batch_size=256,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 53622/53622 [==============================] - 41s 773us/step - loss: 2.6657
#
# Epoch 2/60
# 53622/53622 [==============================] - 40s 753us/step - loss: 2.3953
#
# Epoch 3/60
# 53622/53622 [==============================] - 41s 759us/step - loss: 2.2483
#
# Epoch 4/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 2.1748
#
# Epoch 5/60
# 53622/53622 [==============================] - 41s 758us/step - loss: 2.1198
#
# Epoch 6/60
# 53622/53622 [==============================] - 41s 758us/step - loss: 2.0736
#
# Epoch 7/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 2.0272
#
# Epoch 8/60
# 53622/53622 [==============================] - 40s 752us/step - loss: 1.9832
#
# Epoch 9/60
# 53622/53622 [==============================] - 40s 753us/step - loss: 1.9508
#
# Epoch 10/60
# 53622/53622 [==============================] - 41s 759us/step - loss: 1.9096
#
# Epoch 11/60
# 53622/53622 [==============================] - 41s 758us/step - loss: 1.8793
#
# Epoch 12/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 1.8481
#
# Epoch 13/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 1.8166
#
# Epoch 14/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 1.7889
#
# Epoch 15/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 1.7615
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "ver it Properly oh its all getting on top of me And if it we"
# ver it Properly oh its all getting on top of me And if it were a start the say I want to the back I want you let a sear and the store I want the cant the sain and store the sain the start and the stound and the say the strack and the say a store I want the start on the start and the say and a start and the starter and a strange and the store on the starter and the store on the store and the start on the sain the store I want to stelled and the sun the sun
# ----- diversity: 0.5
# ----- Generating with seed: "ver it Properly oh its all getting on top of me And if it we"
# ver it Properly oh its all getting on top of me And if it we go one the said and the say I want I dont be they and the mint and that the stelle Im show you and it and of the thought the bat me stelle And the steands to unting the port Ins and a stowe to me stoat and the suon I wan your to be your have the say and the but of I want to she cause a that it and your dont the call a stine me see the dook Wan the beack And reand been And he want wanna stole and
# ----- diversity: 1.0
# ----- Generating with seed: "ver it Properly oh its all getting on top of me And if it we"
# ver it Properly oh its all getting on top of me And if it welally Fun that ones the the turnerhes e ra of I wognt anowhing my pein Secleons oat wont an a dabes toing As the firders baby your I dont the star had your rour That my stirgs ol it but of my Madco Vmer Or Im a whak Caup The spiges ofly Oubecrone byen Ceor thes a 5ven uncher But my on watce wan exloungss and were you reeaky doce To quarly I dint efore and shat book Yours want go thincibes myin fra
# ----- diversity: 1.2
# ----- Generating with seed: "ver it Properly oh its all getting on top of me And if it we"
# ver it Properly oh its all getting on top of me And if it weet my alisicg to reverrumope Pacgaet flaw Runt beow in I rees He us Miildo Noes os the day baine dotwh um right time time Its assinger ewe scouth they osy nan Byet Wances Auther yourr leagind Bovup gook tryong mak lobacket on and it tryen anderiMaunner And Jayraodia And your hit And it Or Ip the tusnehes the codwuqtu Is lake Phensinabame Wondning anmy watnc um nitine Say of thie higd you Just powh
# Epoch 16/60
# 53622/53622 [==============================] - 40s 754us/step - loss: 1.7390
#
# Epoch 17/60
# 53622/53622 [==============================] - 41s 761us/step - loss: 1.7111
#
# Epoch 18/60
# 53622/53622 [==============================] - 41s 758us/step - loss: 1.6900
#
# Epoch 19/60
# 53622/53622 [==============================] - 41s 758us/step - loss: 1.6655
#
# Epoch 20/60
# 53622/53622 [==============================] - 41s 757us/step - loss: 1.6431
#
# Epoch 21/60
# 53622/53622 [==============================] - 41s 763us/step - loss: 1.6213
#
# Epoch 22/60
# 53622/53622 [==============================] - 44s 826us/step - loss: 1.5996
#
# Epoch 23/60
# 53622/53622 [==============================] - 47s 869us/step - loss: 1.5758
#
# Epoch 24/60
# 53622/53622 [==============================] - 43s 804us/step - loss: 1.5504
#
# Epoch 25/60
# 53622/53622 [==============================] - 41s 765us/step - loss: 1.5319
#
# Epoch 26/60
# 53622/53622 [==============================] - 44s 819us/step - loss: 1.5074
#
# Epoch 27/60
# 53622/53622 [==============================] - 42s 786us/step - loss: 1.4884
#
# Epoch 28/60
# 53622/53622 [==============================] - 42s 787us/step - loss: 1.4754
#
# Epoch 29/60
# 53622/53622 [==============================] - 42s 786us/step - loss: 1.4495
#
# Epoch 30/60
# 53622/53622 [==============================] - 42s 786us/step - loss: 1.4261
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: " the cusp of tryin to kiss you I dont know if you feel the s"
#  the cusp of tryin to kiss you I dont know if you feel the sun the back of the back of the back of the that I wanna be your strain the book the back around the back of the mind a share to shough the store you start to shalala come on the shouss the book And the right not the sun be the conter on the strange And the shoust a say I want to get you were the back of the strange the mine And the port on the strange And the shartine and the say I want to be the
# ----- diversity: 0.5
# ----- Generating with seed: " the cusp of tryin to kiss you I dont know if you feel the s"
#  the cusp of tryin to kiss you I dont know if you feel the shinged and the lights on a latt the book Are you cause you ever sing that I wanna be your from He want to be in the car think The pill stele that your chance you we laurs had a too but it woll me brick on the back I want you were a bet on the tration of the stoping that with you dont want your start out he cant on your hard to me I want to where shine that when you put your thinking and the lights
# ----- diversity: 1.0
# ----- Generating with seed: " the cusp of tryin to kiss you I dont know if you feel the s"
#  the cusp of tryin to kiss you I dont know if you feel the suighing to sere yours were my thirts the exke your shorpems the tiged alright withingin mare Rue i0s and you resp blayed to be I mate bits cole were were might cerer benchar meet shill steline os we was up your listuning beversay when you got a feel come one Trawe hare Or pust And exatall And your menocks theyes With the had Vwoo ache there like your is reapu Sigh Coll Come this done of this the r
# ----- diversity: 1.2
# ----- Generating with seed: " the cusp of tryin to kiss you I dont know if you feel the s"
#  the cusp of tryin to kiss you I dont know if you feel the smagurs know me I evernes Me you slies skoots Ryosance those twove Arraally wolr becings wish you go uf Befly come Im like a dish comre Rets mach zaisi yoursee you ard so teld it dettink exto me runt your wyqk Pryiccly So rouse you lan no Wact with wight we And weal Or the basering chain Heaa if poughinkss a shaws there Thew it tean youve ses cozings alound they ax Thoits the ray on the grumings lu
# Epoch 31/60
# 53622/53622 [==============================] - 42s 786us/step - loss: 1.4042
#
# Epoch 32/60
# 53622/53622 [==============================] - 42s 791us/step - loss: 1.3775
#
# Epoch 33/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.6647
#
# Epoch 34/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.7643
#
# Epoch 35/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.6886
#
# Epoch 36/60
# 53622/53622 [==============================] - 42s 787us/step - loss: 1.6597
#
# Epoch 37/60
# 53622/53622 [==============================] - 44s 820us/step - loss: 1.6102
#
# Epoch 38/60
# 53622/53622 [==============================] - 47s 875us/step - loss: 1.5938
#
# Epoch 39/60
# 53622/53622 [==============================] - 44s 827us/step - loss: 1.5980
#
# Epoch 40/60
# 53622/53622 [==============================] - 43s 798us/step - loss: 1.5913
#
# Epoch 41/60
# 53622/53622 [==============================] - 42s 785us/step - loss: 1.57960s - loss: 1
#
# Epoch 42/60
# 53622/53622 [==============================] - 42s 783us/step - loss: 1.5380
#
# Epoch 43/60
# 53622/53622 [==============================] - 43s 806us/step - loss: 1.5388
#
# Epoch 44/60
# 53622/53622 [==============================] - 42s 785us/step - loss: 1.5645
#
# Epoch 45/60
# 53622/53622 [==============================] - 43s 797us/step - loss: 1.3226
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "us Yeah regardless of whats gone before I want to see all of"
# us Yeah regardless of whats gone before I want to see all of the track And the stars of the back on the strange And the shags And the bark of a snake and stare Im sure the stars of a snake and stare He dont the back on the strange And the sun good on the back And theres a seam We like you had a found the stars of a snake sun that in the strange and the same I was that is the back on the strange And the stars of a snake and stare Home on the strange In the
# ----- diversity: 0.5
# ----- Generating with seed: "us Yeah regardless of whats gone before I want to see all of"
# us Yeah regardless of whats gone before I want to see all of a spack Gands in the blance and talk arai ir and stard Het she looking flom the strange In the strain of for the back of a surd all the poony and were to musser With you cant be to see weal you look around aw evenys your dove are shinking of come on the fat that she love the bottle noth flean of a surd PreChing to there I dont want to see it to like to be yours have a surd I something a start If
# ----- diversity: 1.0
# ----- Generating with seed: "us Yeah regardless of whats gone before I want to see all of"
# us Yeah regardless of whats gone before I want to see all ofly curler reet show exstidaruch Pibsuct as ofver pembed Efechange But be as E fuct When your lindny for with pretter of she like take you caller Or with things beald as a distine Prettering like you were block have housn all the thatch stange and hit Yicker ta b0l go Polbin Lost to me Well I but hersahing To mak in turnenned Sembecked cack some laugh And go and all Gight Lay Oir in your fandbeamin
# ----- diversity: 1.2
# ----- Generating with seed: "us Yeah regardless of whats gone before I want to see all of"
# us Yeah regardless of whats gone before I want to see all offs my baby exoft looks kig oh in teratheres makes all wish If light You easing Wha wonderent might on fir Inchpity oce Kaddo be youvance Oh adl the balk Yeah Dust onitwle And theres lights here wight Its not bus it Im numester Why on Yuton to lakes Im liurd you looking goved Hay grbucklas And Inhtru And oyc tisel and the reather a deavin Oqcart Rut your mator morchorms cannyshesì Do you la1dor on
# Epoch 46/60
# 53622/53622 [==============================] - 42s 785us/step - loss: 1.2411
#
# Epoch 47/60
# 53622/53622 [==============================] - 44s 824us/step - loss: 1.2034
#
# Epoch 48/60
# 53622/53622 [==============================] - 43s 805us/step - loss: 1.1740
#
# Epoch 49/60
# 53622/53622 [==============================] - 44s 816us/step - loss: 1.1511
#
# Epoch 50/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.1252
#
# Epoch 51/60
# 53622/53622 [==============================] - 42s 791us/step - loss: 1.1019
#
# Epoch 52/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.0808
#
# Epoch 53/60
# 53622/53622 [==============================] - 42s 789us/step - loss: 1.0575
#
# Epoch 54/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 1.0376
#
# Epoch 55/60
# 53622/53622 [==============================] - 42s 789us/step - loss: 1.0168
#
# Epoch 56/60
# 53622/53622 [==============================] - 42s 788us/step - loss: 0.9943
#
# Epoch 57/60
# 53622/53622 [==============================] - 42s 784us/step - loss: 0.9749
#
# Epoch 58/60
# 53622/53622 [==============================] - 42s 786us/step - loss: 0.9521
#
# Epoch 59/60
# 53622/53622 [==============================] - 42s 785us/step - loss: 0.9310
#
# Epoch 60/60
# 53622/53622 [==============================] - 42s 785us/step - loss: 0.9102
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: "e the perfect scene Hes nearing the brink but he thinks firs"
# e the perfect scene Hes nearing the brink but he thinks first to set you something on the seats a scouck And his and change InSill of a scouck And theres no no I said it was anthy cause I wanna be yours I wanna be yours I wanna be yours hands store Incorathering and the same I was think off the shags of the strange InSt fall not what he got and she was sound like to me I wanna be yours hands store to shes the only one of you cant they said it come on come
# ----- diversity: 0.5
# ----- Generating with seed: "e the perfect scene Hes nearing the brink but he thinks firs"
# e the perfect scene Hes nearing the brink but he thinks first were too said I he gonna be your seathe And I sun to kiss its just the shumsen And now Im not to end when the shous of acternoon of I left I leavin your storms not what you down to block So I wanna het you are you let her complessions on me I want to see it I send your want befalets The way I can I can sound of the bottle walk the sun but bethee said it not soon were your tonight And I can no in
# ----- diversity: 1.0
# ----- Generating with seed: "e the perfect scene Hes nearing the brink but he thinks firs"
# e the perfect scene Hes nearing the brink but he thinks first like well falkhange As the side Oh she could as infore I dids you arain They just can ank I wanna reande Lott distrught be take su dont dught you can but baby an allick ot sown the ex to seat but if I hop firiday Lidrt then the eyes the feat moxk of for reloof And that you had ut bift toise they show yeah you but that yeah you has thies cant let her mlice you were I wanna briecke And when they u
# ----- diversity: 1.2
# ----- Generating with seed: "e the perfect scene Hes nearing the brink but he thinks firs"
# e the perfect scene Hes nearing the brink but he thinks firsT have leugh Porourqeom of Pust my nably gricn I said Poliver the out of tick think I wanno Oh the felt storking cause I nees your hall bound the dook fancing Surtu afcews So Its hone something her its scrien your vrlit it dried Its not the twisss dont me is for the chict think a Presenfuse that they wantiO is on well you know when you let her When trunough morous Them trous dons to mebem Don Baby
